# %% [markdown]
# <a href="https://colab.research.google.com/github/chahyeonseong/chahyeonseong/blob/main/GIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
fig = plt.figure()

# %%
df = pd.DataFrame(np.random.randn(5,5))

# %%
df
# Out:
#           0         1         2         3         4
# 0 -1.831645 -0.196363 -0.269419  0.075980 -1.145822
# 1 -1.128024 -1.906705 -1.157457  1.225061  1.373258
# 2  0.652574 -0.015774 -0.298490 -0.869792  1.639613
# 3 -1.337152 -1.182761 -1.292478 -1.666630  0.194652
# 4  1.243927  0.668726  0.475813 -1.510897 -0.077343

# %%
df.plot()

# %%
df.plot(kind = "barh")

# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", style = "smoker", data = tips)

# %%
iris = sns.load_dataset("iris")

# %%
penguins = sns.load_dataset("penguins")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
x = iris["sepal_length"]

# %%
sns.histplot(x= x, kde = True)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(data = iris, x = "sepal_length", y = "petal_length", cbar = True)

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.histplot(data = penguins, x = "bill_length_mm", hue = "species", multiple = "stack")

# %%
sns.histplot(data = penguins, x = "bill_length_mm", hue = "species", multiple = "dodge")

# %%
sns.pairplot(iris)

# %%
flights = sns.load_dataset("flights")

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights = flights.pivot("month", "year", "passengers")

# %%
sns.heatmap(flights)

# %%
plt.figure(figsize = (10,10))
sns.heatmap(flights)

# %%
plt.figure(figsize = (10,10))
sns.heatmap(flights, annot = True, fmt = "d")

# %%
import folium #지도를 띄워주는 패키지요

# %%
m = folium.Map(location = [37.5665734, 126.978179])

folium.Marker(location = [37.5665734, 126.978179], popup = "서울시청", icon = folium.Icon(icon_color = "blue")).add_to(m)
folium.Marker(location = [37.5806736, 126.976952], popup = "경복궁", icon = folium.Icon(icon_color = "orange")).add_to(m)
folium.Marker(location = [37.5659240, 126.975010], popup = "국립현대미술관", icon = folium.Icon(icon_color = "red")).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
center = [37.5665734, 126.978179]
m = folium.Map(location = center, zoom_start = 10)

location_data = [37.5665734, 126.978179],[37.5806736, 126.976952],[37.5659240, 126.975010]

# %%
folium.PolyLine(locations = location_data, tooltip = "PolyLine").add_to(m)

# %%
folium.Marker(location = [37.5665734, 126.978179], popup = "서울시청", icon = folium.Icon(icon_color = "blue")).add_to(m)
folium.Marker(location = [37.5806736, 126.976952], popup = "경복궁", icon = folium.Icon(icon_color = "orange")).add_to(m)
folium.Marker(location = [37.5659240, 126.975010], popup = "국립현대미술관", icon = folium.Icon(icon_color = "red")).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
folium.Polygon(locations = location_data, tooltip = "PolyLine").add_to(m)

# %%
folium.Polygon(locations = location_data, tooltip = "PolyLine").add_to(m)

# %%
folium.Marker(location = [37.5665734, 126.978179], popup = "서울시청", icon = folium.Icon(icon_color = "blue")).add_to(m)
folium.Marker(location = [37.5806736, 126.976952], popup = "경복궁", icon = folium.Icon(icon_color = "orange")).add_to(m)
folium.Marker(location = [37.5659240, 126.975010], popup = "국립현대미술관", icon = folium.Icon(icon_color = "red")).add_to(m)
m

# %%
folium.Polygon(locations = location_data, fill = True, tooltip = "PolyLine").add_to(m)

# %%
folium.Marker(location = [37.5665734, 126.978179], popup = "서울시청", icon = folium.Icon(icon_color = "blue")).add_to(m)
folium.Marker(location = [37.5806736, 126.976952], popup = "경복궁", icon = folium.Icon(icon_color = "orange")).add_to(m)
folium.Marker(location = [37.5659240, 126.975010], popup = "국립현대미술관", icon = folium.Icon(icon_color = "red")).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#우리 지점을 포함하는 사각형과 원 그려보기

folium.Rectangle(bounds = location_data, tooltip = "Rectangle").add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
folium.Circle([37.5665734, 126.978179], radius = 300).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
